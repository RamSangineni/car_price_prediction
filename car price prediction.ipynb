# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("CarPrice_Assignment.csv")
df.head(5)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(5)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
## insurance risk ratings
value_counts = df['symboling'].value_counts()

# Create a bar plot
plt.bar(value_counts.index, value_counts.values)

# Add labels and title
plt.xlabel('Insurance Risk Rating')
plt.ylabel('Count')
plt.title('Insurance Risk Rating Distribution')

# Show the plot
plt.show()

# %%
# Assuming df['fueltype'] contains the fuel types
fuel_types_value_counts = df['fueltype'].value_counts()

# Define colors for each fuel type
colors = ['blue', 'green']

# Create a bar plot with different colors
plt.bar(fuel_types_value_counts.index, fuel_types_value_counts.values, color=colors)

# Add labels and title
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.title('Distribution of Fuel Types')

# Show the plot
plt.show()

# %%
aspirations_value_counts = df['aspiration'].value_counts()

# Define colors for each aspiration (e.g., 'std' and 'turbo')
colors = ['blue', 'green']

# Create a bar plot with different colors
plt.bar(aspirations_value_counts.index, aspirations_value_counts.values, color=colors)

# Add labels and title
plt.xlabel('Aspiration Type')
plt.ylabel('Count')
plt.title('Distribution of Aspirations in Cars')

# Show the plot
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
# Summary statistics for numeric columns
numeric_columns = ['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
                   'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower', 'peakrpm',
                   'citympg', 'highwaympg', 'price']

summary_stats = df[numeric_columns].describe()
print(summary_stats)
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %% [markdown]
# ## Histograms:

# %%
# Histograms for numeric variables
plt.figure(figsize=(16, 10))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(4, 4, i)
    sns.histplot(data=df, x=col, kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Pairwise Scatterplots:

# %%
# Pairwise scatterplots for numeric variables
sns.pairplot(df[numeric_columns])
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
# Correlation heatmap
correlation_matrix = df[numeric_columns].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", square=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Box Plots for Categorical Variables:

# %%
# Box plots for categorical vs. numeric variables
categorical_columns = ['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']

plt.figure(figsize=(16, 12))
for i, cat_col in enumerate(categorical_columns, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(data=df, x=cat_col, y='price')
    plt.title(f'{cat_col} vs. Price')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### There are outliers in some of the features, removing outliers

# %%
# List of categorical variables
categorical_columns = ['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']

# Function to cap outliers within each category
def cap_outliers_within_category(data, cat_col, num_col):
    categories = data[cat_col].unique()

    for category in categories:
        subset = data[data[cat_col] == category]
        Q1 = subset[num_col].quantile(0.25)
        Q3 = subset[num_col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Cap the outliers at the upper bound within each category
        data.loc[(data[cat_col] == category) & (data[num_col] > upper_bound), num_col] = upper_bound

# Cap outliers for each categorical vs. numeric variable
plt.figure(figsize=(16, 12))
for i, cat_col in enumerate(categorical_columns, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(data=df, x=cat_col, y='price')
    plt.title(f'{cat_col} vs. Price')
    plt.xticks(rotation=45)
    
    # Cap outliers for the current categorical variable
    cap_outliers_within_category(df, cat_col, 'price')

plt.tight_layout()
plt.show()

# %%
#correlation
df.corr()
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
#selecting features 
df1=df[['fueltype', 'aspiration', 'carbody', 'drivewheel', 'enginetype', 'cylindernumber', 'fuelsystem','symboling','enginesize',
    'boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg','price']]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fueltype          205 non-null    object
#  1   aspiration        205 non-null    object
#  2   carbody           205 non-null    object
#  3   drivewheel        205 non-null    object
#  4   enginetype        205 non-null    object
#  5   cylindernumber    205 non-null    object
#  6   fuelsystem        205 non-null    object
#  7   symboling         205 non-null    int64
#  8   enginesize        205 non-null    int64
#  9   boreratio         205 non-null    float64
#  10  stroke            205 non-null    float64
#  11  compressionratio  205 non-null    float64
#  12  horsepower        205 non-null    int64
#  13  peakrpm           205 non-null    int64
#  14  citympg           205 non-null    int64
#  15  highwaympg        205 non-null    int64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## selecting features which are neccessary for car price prediction, discarding rest of the features

# %%
# Split the data into training and testing sets
X = df1.drop(columns=['price'])  # Features
Y = df1['price']  # Target variable

# %%
label_encoder = LabelEncoder()

# %%
categorical_columns = X[['fueltype', 'aspiration', 'carbody', 'drivewheel', 'enginetype', 'cylindernumber', 'fuelsystem']]

# %%
# Applying label encoding to each categorical column
for column in categorical_columns:
    X[column] = label_encoder.fit_transform(X[column])

# %%
numeric_columns = X.select_dtypes(include=['int64', 'float64'])

# %%
numeric_columns=numeric_columns[['symboling','enginesize','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg']]

# %%
# Create a StandardScaler object
scaler = StandardScaler()

# %%
# Applying STANDARD SCALING to each numeric column
for column in numeric_columns:
    # Reshape the column to a 2D array before scaling
    X[column] = scaler.fit_transform(X[column].values.reshape(-1, 1))

# %%
## After Encoding categorical features & scaling Numerical features
X.head(5)
# Out:
#    fueltype  aspiration  carbody  drivewheel  enginetype  cylindernumber  \
# 0         1           0        0           2           0               2
# 1         1           0        0           2           0               2
# 2         1           0        2           2           5               3
# 3         1           0        3           1           3               2
# 4         1           0        3           0           3               1
#
#    fuelsystem  symboling  enginesize  boreratio    stroke  compressionratio  \
# 0           5   1.743470    0.074449   0.519071 -1.839377         -0.288349
# 1           5   1.743470    0.074449   0.519071 -1.839377         -0.288349
# 2           5   0.133509    0.604046  -2.404880  0.685946         -0.288349
# 3           5   0.938490   -0.431076  -0.517266  0.462183         -0.035973
# 4           5   0.938490    0.218885  -0.517266  0.462183         -0.540725
#
#    horsepower   peakrpm   citympg  highwaympg
# ...

# %%
###Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
##Build and Train the Regression Model
model = Pipeline([
    ('regressor', RandomForestRegressor(random_state=42))
])

# %%
model.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('regressor', RandomForestRegressor(random_state=42))])

# %%
### Evaluate the Model
Y_pred = model.predict(X_test)

# %%
mae = mean_absolute_error(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

# %%
print('mean absolute error :',mae)
print('mean squared error :',mse)
print('r2_score :',r2)a
# Out:
# mean absolute error : 1361.0009385525552
# mean squared error : 2708943.788351687
# r2_score : 0.9193504324452837

# %% [markdown]
# ## prediction

# %%
# Use the trained model to make a prediction with the correct features
prediction_features = [[1, 3, 3.19, 3.40, 10.0, 102, 5500, 24, 30]]
predicted_price = model.predict(prediction_features)
print("Predicted Price:", predicted_price)
# Out:
# Predicted Price: [14505.010625]

# %%
plot
